# %%
import pandas as pd
import csv

path="C://Users//oorte//Documents//RICE-CLASS-MATERIAL//team3//US_Accidents_June20.csv"
traffic_df = pd.read_csv(path)

# %%
traffic_df
# Out:
#                 ID    Source    TMC  Severity           Start_Time  \
# 0              A-1  MapQuest  201.0         3  2016-02-08 05:46:00
# 1              A-2  MapQuest  201.0         2  2016-02-08 06:07:59
# 2              A-3  MapQuest  201.0         2  2016-02-08 06:49:27
# 3              A-4  MapQuest  201.0         3  2016-02-08 07:23:34
# 4              A-5  MapQuest  201.0         2  2016-02-08 07:39:07
# ...            ...       ...    ...       ...                  ...
# 3513612  A-3513776      Bing    NaN         2  2019-08-23 18:03:25
# 3513613  A-3513777      Bing    NaN         2  2019-08-23 19:11:30
# 3513614  A-3513778      Bing    NaN         2  2019-08-23 19:00:21
# 3513615  A-3513779      Bing    NaN         2  2019-08-23 19:00:21
# 3513616  A-3513780      Bing    NaN         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  ...  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN  ...
# ...

# %%
import time 
import datetime
import numpy as np

# %%
 
string1 = traffic_df["Start_Time"][0]
string2 = traffic_df["End_Time"][0]

# %%
date_time_obj1 = datetime.datetime.strptime(string1, '%Y-%m-%d %H:%M:%S')
date_time_obj2 = datetime.datetime.strptime(string2, '%Y-%m-%d %H:%M:%S')

# %%
a = datetime.datetime.timestamp(date_time_obj1)
b = datetime.datetime.timestamp(date_time_obj2)
print(a,b)
# Out:
# 1454931960.0 1454950800.0

# %%
date_time_objd = date_time_obj2-date_time_obj1
date_time_objd
# Out:
# datetime.timedelta(seconds=18840)

# %%
# Read strings representing Start and End of accident
date_start=traffic_df["Start_Time"].str.split(expand=True)
date_end=traffic_df["End_Time"].str.split(expand=True)

# %%
#Get the year
s=date_start[0].str[:4]
t=date_start[0].str[:4]
traffic_df['year_start']=pd.to_numeric(s, downcast='unsigned')
traffic_df['year_end']=pd.to_numeric(t, downcast='unsigned')
# Out:
#                 ID    Source    TMC  Severity           Start_Time  \
# 0              A-1  MapQuest  201.0         3  2016-02-08 05:46:00
# 1              A-2  MapQuest  201.0         2  2016-02-08 06:07:59
# 2              A-3  MapQuest  201.0         2  2016-02-08 06:49:27
# 3              A-4  MapQuest  201.0         3  2016-02-08 07:23:34
# 4              A-5  MapQuest  201.0         2  2016-02-08 07:39:07
# ...            ...       ...    ...       ...                  ...
# 3513612  A-3513776      Bing    NaN         2  2019-08-23 18:03:25
# 3513613  A-3513777      Bing    NaN         2  2019-08-23 19:11:30
# 3513614  A-3513778      Bing    NaN         2  2019-08-23 19:00:21
# 3513615  A-3513779      Bing    NaN         2  2019-08-23 19:00:21
# 3513616  A-3513780      Bing    NaN         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  ...  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN  ...
# ...

# %%
#Get the month
traffic_df['month_start']=int(date_start[0].str[5:7])
traffic_df['month_end']=int(date_end[0].str[5:7])

# %%
#Get the day
traffic_df['day_start']=date_start[0].str[8:10]
traffic_df['day_end']=date_end[0].str[8:10]

# %%
#Get the time
traffic_df['time_start']=date_start[0].str[8:10]
traffic_df['time_end']=date_end[0].str[8:10]
traffic_df
# Out:
#                 ID    Source    TMC  Severity           Start_Time  \
# 0              A-1  MapQuest  201.0         3  2016-02-08 05:46:00
# 1              A-2  MapQuest  201.0         2  2016-02-08 06:07:59
# 2              A-3  MapQuest  201.0         2  2016-02-08 06:49:27
# 3              A-4  MapQuest  201.0         3  2016-02-08 07:23:34
# 4              A-5  MapQuest  201.0         2  2016-02-08 07:39:07
# ...            ...       ...    ...       ...                  ...
# 3513612  A-3513776      Bing    NaN         2  2019-08-23 18:03:25
# 3513613  A-3513777      Bing    NaN         2  2019-08-23 19:11:30
# 3513614  A-3513778      Bing    NaN         2  2019-08-23 19:00:21
# 3513615  A-3513779      Bing    NaN         2  2019-08-23 19:00:21
# 3513616  A-3513780      Bing    NaN         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  ...  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN  ...
# ...
