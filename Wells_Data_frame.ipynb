# %%
import pandas as pd

data = pd.read_csv('ks_wells.txt', header='infer', sep=',', delimiter=None)
## data.columns = ["a", "b", "c", "etc."]

# %%
data
# Out:
#                KID         API_NUMBER  API_NUM_NODASH          LEASE     WELL  \
# 0       1001184201       15-007-20008    1.500720e+13  Kirkbride 'B'        1
# 1       1001184206       15-007-20013    1.500720e+13        SLEEPER      1-W
# 2       1001184249       15-007-20056    1.500720e+13  Winters, W.W.        1
# 3       1001184287       15-007-20094    1.500720e+13    Stonestreet        1
# 4       1001184375       15-007-20184    1.500720e+13        Lenkner        1
# ...            ...                ...             ...            ...      ...
# 489895  1046936256  15-009-25779-0002    1.500926e+13   DOONAN A SWD        2
# 489896  1046936257       15-059-01620    1.505902e+13      E. SEYLER   ESY 01
# 489897  1046936258       15-121-02739    1.512103e+13        KEMPLEY   KEM 01
# 489898  1046936259       15-003-26641    1.500327e+13         DONLEY       38
# 489899  1046936260       15-133-02733    1.513303e+13            MIH  MIH OW1
#
# ...
